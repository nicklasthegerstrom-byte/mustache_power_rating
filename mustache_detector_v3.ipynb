# %% [markdown]
# # Mustache Detector v3
# Pipeline som automatiskt:
# 1. Skapar dataset med män + kvinnor
# 2. Tränar en första modell
# 3. Använder modellen för att hitta och flytta felmärkta clean-bilder
# 4. Tränar om på rensad data
# 5. Sparar slutlig modell

# %%
import pandas as pd
import os
import shutil
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

print('TensorFlow:', tf.__version__)
# Out:
# TensorFlow: 2.16.2

# %% [markdown]
# ## 1. Ladda och filtrera data

# %%
labels     = pd.read_csv('data/list_attr_celeba.csv')
source_dir = 'data/img/img_align_celeba'

men   = labels[labels['Male'] ==  1]
women = labels[labels['Male'] == -1]

mustache_df = men[men['Mustache'] == 1]
men_clean   = men[men['Mustache'] == -1]
women_black_hair = women[
    (women['Mustache'] == -1) & 
    (women['Black_Hair'] == 1)
].sample(n=2000, random_state=42)

women_other = women[
    (women['Mustache'] == -1) & 
    (women['Black_Hair'] == -1)
].sample(n=1000, random_state=42)

women_clean = pd.concat([women_black_hair, women_other])
clean_df    = pd.concat([men_clean, women_clean])

# Första modellen — 6000 per klass (städas sedan i steg 5)
mustache_sample = mustache_df.sample(n=5000, random_state=42)
clean_sample    = clean_df.sample(n=5000, random_state=42)

print(f'Mustasch: {len(mustache_sample)}')
print(f'Clean:    {len(clean_sample)}')
# Out:
# Mustasch: 5000
# Clean:    5000

# %% [markdown]
# ## 2. Kopiera bilder till dataset_v3

# %%
MUSTACHE_DIR = 'data/dataset_v3/mustache'
CLEAN_DIR    = 'data/dataset_v3/clean'

# Rensa och skapa mappar
if os.path.exists('data/dataset_v3'):
    shutil.rmtree('data/dataset_v3')
os.makedirs(MUSTACHE_DIR)
os.makedirs(CLEAN_DIR)

for filename in mustache_sample['image_id']:
    src = os.path.join(source_dir, filename)
    if os.path.exists(src):
        shutil.copy2(src, os.path.join(MUSTACHE_DIR, filename))

for filename in clean_sample['image_id']:
    src = os.path.join(source_dir, filename)
    if os.path.exists(src):
        shutil.copy2(src, os.path.join(CLEAN_DIR, filename))

print(f'Mustasch: {len(os.listdir(MUSTACHE_DIR))}')
print(f'Clean:    {len(os.listdir(CLEAN_DIR))}')
# Out:
# Mustasch: 5000
# Clean:    5000

# %% [markdown]
# ## 3. Ladda dataset och bygg modell

# %%
IMG_SIZE   = (128, 128)
BATCH_SIZE = 32

def load_datasets(data_dir):
    train_ds = tf.keras.utils.image_dataset_from_directory(
        data_dir,
        validation_split=0.2,
        subset='training',
        seed=42,
        image_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        label_mode='binary'
    )
    val_ds = tf.keras.utils.image_dataset_from_directory(
        data_dir,
        validation_split=0.2,
        subset='validation',
        seed=42,
        image_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        label_mode='binary'
    )
    return train_ds, val_ds

def build_model():
    data_augmentation = tf.keras.Sequential([
        tf.keras.layers.RandomFlip('horizontal'),
        tf.keras.layers.RandomRotation(0.1),
        tf.keras.layers.RandomZoom(0.1),
        tf.keras.layers.RandomBrightness(0.2),
        tf.keras.layers.RandomContrast(0.2),
    ])
    model = tf.keras.Sequential([
        data_augmentation,
        tf.keras.layers.Rescaling(1./255),
        tf.keras.layers.Conv2D(32, 3, activation='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(64, 3, activation='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(128, 3, activation='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.4),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    return model

def train_model(model, train_ds, val_ds, epochs=35, patience=5):
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    early_stop = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=patience,
        restore_best_weights=True,
        verbose=1
    )
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
        callbacks=[early_stop]
    )
    return history

print('Funktioner redo!')
# Out:
# Funktioner redo!

# %% [markdown]
# ## 4. Träna första modellen

# %%
train_ds, val_ds = load_datasets('data/dataset_v3')
print('Klasser:', train_ds.class_names)

model_v1 = build_model()
history1 = train_model(model_v1, train_ds, val_ds)

loss, acc = model_v1.evaluate(val_ds)
print(f'\nFörsta modellen accuracy: {acc*100:.1f}%')
# Out:
# Found 10000 files belonging to 2 classes.
# Using 8000 files for training.
# Found 10000 files belonging to 2 classes.
# Using 2000 files for validation.
# Klasser: ['clean', 'mustache']
# Epoch 1/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 52s 198ms/step - accuracy: 0.5715 - loss: 0.6783 - val_accuracy: 0.6810 - val_loss: 0.6106
# Epoch 2/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 185ms/step - accuracy: 0.6628 - loss: 0.6124 - val_accuracy: 0.7615 - val_loss: 0.5206
# Epoch 3/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 184ms/step - accuracy: 0.7451 - loss: 0.5320 - val_accuracy: 0.7315 - val_loss: 0.5486
# Epoch 4/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 44s 177ms/step - accuracy: 0.7753 - loss: 0.4906 - val_accuracy: 0.8160 - val_loss: 0.4221
# Epoch 5/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 179ms/step - accuracy: 0.7881 - loss: 0.4704 - val_accuracy: 0.8180 - val_loss: 0.4274
# Epoch 6/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 44s 177ms/step - accuracy: 0.7983 - loss: 0.4459 - val_accuracy: 0.8170 - val_loss: 0.4256
# Epoch 7/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 182ms/step - accuracy: 0.8052 - loss: 0.4374 - val_accuracy: 0.8185 - val_loss: 0.4142
# Epoch 8/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 179ms/step - accuracy: 0.8085 - loss: 0.4307 - val_accuracy: 0.8385 - val_loss: 0.3852
# Epoch 9/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 182ms/step - accuracy: 0.8198 - loss: 0.4237 - val_accuracy: 0.8295 - val_loss: 0.3955
# Epoch 10/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 48s 193ms/step - accuracy: 0.8200 - loss: 0.4170 - val_accuracy: 0.8270 - val_loss: 0.3974
# Epoch 11/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 48s 190ms/step - accuracy: 0.8234 - loss: 0.4098 - val_accuracy: 0.8355 - val_loss: 0.3860
# Epoch 12/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 181ms/step - accuracy: 0.8217 - loss: 0.4098 - val_accuracy: 0.8410 - val_loss: 0.3761
# Epoch 13/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 183ms/step - accuracy: 0.8298 - loss: 0.3944 - val_accuracy: 0.8380 - val_loss: 0.3764
# Epoch 14/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 196ms/step - accuracy: 0.8320 - loss: 0.3922 - val_accuracy: 0.8330 - val_loss: 0.3823
# Epoch 15/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 180ms/step - accuracy: 0.8313 - loss: 0.3958 - val_accuracy: 0.8440 - val_loss: 0.3602
# Epoch 16/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 47s 188ms/step - accuracy: 0.8334 - loss: 0.3858 - val_accuracy: 0.8390 - val_loss: 0.3836
# Epoch 17/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 179ms/step - accuracy: 0.8364 - loss: 0.3861 - val_accuracy: 0.8380 - val_loss: 0.3739
# Epoch 18/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 178ms/step - accuracy: 0.8378 - loss: 0.3814 - val_accuracy: 0.8430 - val_loss: 0.3753
# Epoch 19/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 44s 177ms/step - accuracy: 0.8345 - loss: 0.3794 - val_accuracy: 0.8500 - val_loss: 0.3573
# Epoch 20/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 182ms/step - accuracy: 0.8391 - loss: 0.3755 - val_accuracy: 0.8520 - val_loss: 0.3640
# Epoch 21/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 197ms/step - accuracy: 0.8430 - loss: 0.3690 - val_accuracy: 0.8530 - val_loss: 0.3502
# Epoch 22/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 184ms/step - accuracy: 0.8400 - loss: 0.3811 - val_accuracy: 0.8435 - val_loss: 0.3659
# Epoch 23/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 196ms/step - accuracy: 0.8449 - loss: 0.3680 - val_accuracy: 0.8525 - val_loss: 0.3584
# Epoch 24/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 48s 193ms/step - accuracy: 0.8446 - loss: 0.3662 - val_accuracy: 0.8465 - val_loss: 0.3552
# Epoch 25/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 51s 206ms/step - accuracy: 0.8440 - loss: 0.3732 - val_accuracy: 0.8535 - val_loss: 0.3480
# Epoch 26/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 184ms/step - accuracy: 0.8443 - loss: 0.3654 - val_accuracy: 0.8545 - val_loss: 0.3496
# Epoch 27/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 180ms/step - accuracy: 0.8471 - loss: 0.3594 - val_accuracy: 0.8390 - val_loss: 0.3628
# Epoch 28/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 179ms/step - accuracy: 0.8461 - loss: 0.3630 - val_accuracy: 0.8500 - val_loss: 0.3534
# Epoch 29/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 182ms/step - accuracy: 0.8457 - loss: 0.3575 - val_accuracy: 0.8465 - val_loss: 0.3581
# Epoch 30/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 186ms/step - accuracy: 0.8490 - loss: 0.3581 - val_accuracy: 0.8520 - val_loss: 0.3406
# Epoch 31/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 54s 215ms/step - accuracy: 0.8537 - loss: 0.3509 - val_accuracy: 0.8555 - val_loss: 0.3453
# Epoch 32/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 51s 203ms/step - accuracy: 0.8511 - loss: 0.3559 - val_accuracy: 0.8450 - val_loss: 0.3611
# Epoch 33/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 51s 202ms/step - accuracy: 0.8533 - loss: 0.3534 - val_accuracy: 0.8560 - val_loss: 0.3471
# Epoch 34/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 51s 205ms/step - accuracy: 0.8522 - loss: 0.3463 - val_accuracy: 0.8485 - val_loss: 0.3540
# Epoch 35/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 51s 204ms/step - accuracy: 0.8509 - loss: 0.3499 - val_accuracy: 0.8365 - val_loss: 0.3877
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 30.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.8520 - loss: 0.3406
#
# Första modellen accuracy: 85.2%

# %% [markdown]
# ## 5. Hitta och flytta felmärkta clean-bilder

# %%
# DEL 1 — Hitta felmärkta och visa dem

NOISE_THRESHOLD = 0.7

clean_files = os.listdir(CLEAN_DIR)
scores = []

for i, fname in enumerate(clean_files):
    path = os.path.join(CLEAN_DIR, fname)
    img  = tf.keras.utils.load_img(path, target_size=IMG_SIZE)
    arr  = np.expand_dims(tf.keras.utils.img_to_array(img), axis=0)
    prob = float(model_v1.predict(arr, verbose=0)[0][0])
    scores.append((fname, prob))
    if (i + 1) % 1000 == 0:
        print(f'{i+1}/{len(clean_files)} klara...')

to_move = [(f, s) for f, s in scores if s > NOISE_THRESHOLD]
print(f'Hittade {len(to_move)} felmärkta bilder (>{NOISE_THRESHOLD*100:.0f}%)')

# Visa topp 25
plt.figure(figsize=(15, 15))
for i, (fname, score) in enumerate(sorted(to_move, key=lambda x: x[1], reverse=True)[:25]):
    img = Image.open(os.path.join(CLEAN_DIR, fname))
    plt.subplot(5, 5, i + 1)
    plt.imshow(img)
    plt.title(f'{score*100:.0f}%')
    plt.axis('off')
plt.suptitle('Felmärkta clean-bilder — ser rimligt ut?', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# 1000/5000 klara...
# 2000/5000 klara...
# 3000/5000 klara...
# 4000/5000 klara...
# 5000/5000 klara...
# Hittade 526 felmärkta bilder (>70%)

# %%
# DEL 2 — Flytta och balansera

for fname, score in to_move:
    shutil.move(os.path.join(CLEAN_DIR, fname), os.path.join(MUSTACHE_DIR, fname))

print(f'Flyttade {len(to_move)} felmärkta → mustache')

already_used = set(clean_sample['image_id'])
women_pool   = women[(women['Mustache'] == -1) & (women['Black_Hair'] == 1)]
women_pool   = women_pool[~women_pool['image_id'].isin(already_used)]

n_mustache = len(os.listdir(MUSTACHE_DIR))
n_clean    = len(os.listdir(CLEAN_DIR))
n_needed   = n_mustache - n_clean

print(f'Behöver {n_needed} fler bilder i clean för balans')

fill = women_pool.sample(n=n_needed, random_state=99)

for filename in fill['image_id']:
    src = os.path.join(source_dir, filename)
    dst = os.path.join(CLEAN_DIR, filename)
    if os.path.exists(src) and not os.path.exists(dst):
        shutil.copy2(src, dst)

print(f'Clean nu:    {len(os.listdir(CLEAN_DIR))}')
print(f'Mustache nu: {len(os.listdir(MUSTACHE_DIR))}')
# Out:
# Flyttade 526 felmärkta → mustache
# Behöver 1052 fler bilder i clean för balans
# Clean nu:    5526
# Mustache nu: 5526

# %% [markdown]
# ## 6. Träna om på rensad data

# %%
train_ds2, val_ds2 = load_datasets('data/dataset_v3')

print(f'Mustasch: {len(os.listdir(MUSTACHE_DIR))}')
print(f'Clean:    {len(os.listdir(CLEAN_DIR))}')

model_v2 = build_model()
history2 = train_model(model_v2, train_ds2, val_ds2)

loss, acc = model_v2.evaluate(val_ds2)
print(f'\nSlutlig modell accuracy: {acc*100:.1f}%')
# Out:
# Found 11052 files belonging to 2 classes.
# Using 8842 files for training.
# Found 11052 files belonging to 2 classes.
# Using 2210 files for validation.
# Mustasch: 5526
# Clean:    5526
# Epoch 1/35
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 55s 193ms/step - accuracy: 0.5903 - loss: 0.6630 - val_accuracy: 0.7738 - val_loss: 0.5077
# Epoch 2/35
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 54s 194ms/step - accuracy: 0.7645 - loss: 0.4930 - val_accuracy: 0.8670 - val_loss: 0.3325
# Epoch 3/35
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 51s 183ms/step - accuracy: 0.8201 - loss: 0.4114 - val_accuracy: 0.8724 - val_loss: 0.2980
# Epoch 4/35
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 54s 196ms/step - accuracy: 0.8392 - loss: 0.3702 - val_accuracy: 0.8846 - val_loss: 0.2731
# Epoch 5/35
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 64s 230ms/step - accuracy: 0.8505 - loss: 0.3431 - val_accuracy: 0.8950 - val_loss: 0.2474
# Epoch 6/35
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 56s 203ms/step - accuracy: 0.8499 - loss: 0.3392 - val_accuracy: 0.8833 - val_loss: 0.2732
# Epoch 7/35
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 51s 184ms/step - accuracy: 0.8662 - loss: 0.3162 - val_accuracy: 0.8864 - val_loss: 0.2512
# Epoch 8/35
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 50s 182ms/step - accuracy: 0.8685 - loss: 0.2996 - val_accuracy: 0.8991 - val_loss: 0.2266
# Epoch 9/35
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 52s 189ms/step - accuracy: 0.8756 - loss: 0.2937 - val_accuracy: 0.9014 - val_loss: 0.2352
# Epoch 10/35
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 53s 191ms/step - accuracy: 0.8797 - loss: 0.2882 - val_accuracy: 0.9086 - val_loss: 0.2167
# Epoch 11/35
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 54s 194ms/step - accuracy: 0.8827 - loss: 0.2808 - val_accuracy: 0.8995 - val_loss: 0.2245
# Epoch 12/35
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 52s 189ms/step - accuracy: 0.8843 - loss: 0.2723 - val_accuracy: 0.9054 - val_loss: 0.2277
# Epoch 13/35
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 52s 187ms/step - accuracy: 0.8833 - loss: 0.2731 - val_accuracy: 0.9036 - val_loss: 0.2210
# Epoch 14/35
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 50s 181ms/step - accuracy: 0.8852 - loss: 0.2679 - val_accuracy: 0.9027 - val_loss: 0.2335
# Epoch 15/35
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 50s 181ms/step - accuracy: 0.8903 - loss: 0.2581 - val_accuracy: 0.9023 - val_loss: 0.2347
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 10.
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9086 - loss: 0.2167
#
# Slutlig modell accuracy: 90.9%

# %% [markdown]
# ## 7. Utvärdering

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].plot(history2.history['accuracy'], label='Train')
axes[0].plot(history2.history['val_accuracy'], label='Validation')
axes[0].set_title('Accuracy')
axes[0].legend()
axes[1].plot(history2.history['loss'], label='Train')
axes[1].plot(history2.history['val_loss'], label='Validation')
axes[1].set_title('Loss')
axes[1].legend()
plt.tight_layout()
plt.savefig('presentation/training_curves_mustache.png', dpi=150, bbox_inches='tight')
plt.show()

y_true, y_pred = [], []
for images, labels_batch in val_ds2:
    preds = model_v2.predict(images, verbose=0).flatten()
    y_true.extend(labels_batch.numpy().astype(int))
    y_pred.extend((preds > 0.5).astype(int))

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(cm, display_labels=val_ds2.class_names)
disp.plot(values_format='d', cmap='Blues')
plt.title('Mustache Detector v3')
plt.savefig('presentation/confusion_mustache_v3.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# 2026-06-07 21:21:16.742805: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ## 8. Spara modellen

# %%
os.makedirs('models', exist_ok=True)
model_v2.save('models/mustache_detector2.keras')
print('Sparad: models/mustache_detector2.keras')
# Out:
# Sparad: models/mustache_detector2.keras
